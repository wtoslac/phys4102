# %% [markdown]
# Picture of the Muon Experiment:
#
# ![Untitled.png](attachment:9f2791cb-8d41-409a-addb-a2ed38fe8df5.png)
#
# This is the schematic of the Experiment:
#
# ![Untitled-1.png](attachment:2874bcf7-382a-48fd-8fa4-da730f6c5136.png)
#
# Now you have your data:
#
# ![Untitled.png](attachment:7a872399-0576-4f73-b0cf-02d1685349d6.png)
#
# Now we need to analyze the data, this will typically mean making some plots to figure the pattern in the data.
#
# For more documentation look in matplotlib's FAQ
# https://matplotlib.org/2.0.2/faq/usage_faq.html
#
# A picture is worth a thousand word, in science a plot is worth millions sometimes billions of dollars.
#
# Captioning a figure is EXTREMELY important.
# Reader NEEDS to be reminder of the information and the conclusion that they should draw for EVERY FIGURE.
#
# ![Untitled-1.png](attachment:a4e60ea4-ebbf-4527-a8c9-4fff0b3f3b6b.png)
# ### Figure 1: Distribution of the invariant mass of the four leptons selected in the ATLAS measurement of H→ZZ*→4ℓ using the full Run 2 dataset. The Higgs boson corresponds to the excess of events (blue) over the non-resonant ZZ* background (red) at 125 GeV. A rare Z boson decay into four leptons can also be observed at about 91 GeV.
# (Image: ATLAS Collaboration/CERN)

# %% [markdown]
# ### The Markdown Quick Start
#
# You can see that eventhough I am running a python program above, what you see in the box here is human language instead.
#
# This is one of the cool thing about Jupyter Notebook. It allows you to write in Humanish and Python on the same interface and weave them together to explain what you're doing.
#
# This box is known as a Markdown.
#
# <h4> You can make Headers by putting # , ##, ### .... 6# to make them in headers like above</h4>
#
# # Header1
#
# ## Header2
#
# ### Header3
#
# ###### Header6
#
#
# To change the font size from the default use
# <h3>
#     line1<br>
#     line2<br>
#     line3<br>
# </h3>
#
# <h4> You can also make math symbols with LaTEX convention by putting dollar signs around things
# <br>
#
# $ F_g = \frac{G M m}{r^2} $
#
#
# $ F_{elec}= \frac{k q_1 q_2 }{r^2}    $
#
#
# You can make the prints in the markdown look like python codes also
# ```python
# print("helllo world")
# f = x^2
# this looks like python code
# ```
#
# Create Tables
#
# | Students |  a | a  |
# | ------ | ------ | ------ |
# | Taylor|Sam| Carlos|
# | Laine | Aaron| Roydon|
# | Marina | Josh | German |
#
#
# | This | is   |
# |------  |------|
# |   a    | table|
#
#
# Attach images from your computer
#
# <img src = "MuonDetector.JPG" />
#
# Or you can drag and drop or copy and paste also.
#
# Create links to website
# [Description here](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html)
#
# Here's the link to a Jupyter Markdown Cheat Sheets.<br>
# https://blogs.baruch.cuny.edu/cis3100/?p=52<br>
# https://sqlbak.com/blog/wp-content/uploads/2020/12/Jupyter-Notebook-Markdown-Cheatsheet2.pdf<br>

# %% [markdown]
# ## Chapter 2 Programming for Non-Computer Scientists
#   * The basics
#   * Commenting Codes (in Lab)
#   * If and While Statements
#   * Lists and Arrays
#   * For Loops
#   * Functions
#   * Style
